# %% [markdown]
# <center><a href="https://www.pieriantraining.com/" ><img src="../PTCenteredPurple.png" alt="Pierian Training Logo" /></a></center>

# %% [markdown]
# # Assistant with Files Exercise
#
# **TASK: GIVEN THE FILE: exercise_sales_data.csv LOCATED IN THIS FOLDER, CREATE AN ASSISTANT THAT CAN DO THE FOLLOWING: CREATE A BAR PLOT OF TOTAL DOLLAR PURCHASE AMOUNT PER YEAR.**

# %% [markdown]
# -----

# %% [markdown]
# **TASK: Connect to OpenAI via the client call**

# %% [markdown]
# **TASK: Upload the file "exercise_sales_data.csv" to your OpenAI File Set and mark down its file.id**

# %% [markdown]
# **TASK: Create the assistant with both retrieval tool and code_interpreter tool.**

# %% [markdown]
# **TASK: Create a new thread.**

# %% [markdown]
# **TASK: Create a message asking the model to create a bar plot of the total sum of Purchase Price expenditure per year. Remember to mention the file.id in the file_ids parameter list.**

# %% [markdown]
# **TASK: Create a run to run the message on the thread. Optional: If the model complains about not having access to the file, try adding the file.id in your instructions prompt for that specific run.**

# %% [markdown]
# **TASK: Once the run is completed, print out the messages.**

# %%
# Out:
# ThreadMessage(id='msg_fDit4G9dQRd7c2tpDrF7EuoS', assistant_id=None, content=[MessageContentText(text=Text(annotations=[], value='Create a bar plot of the total sum of Purcase Price expenditure per year.'), type='text')], created_at=1702323451, file_ids=['file-1oQKmU7pmCydZsXGce6oxij4'], metadata={}, object='thread.message', role='user', run_id=None, thread_id='thread_cepzPPkT74nYkduAy6aVrFTa')
#
#
# ThreadMessage(id='msg_LU8iRsRfemBfJ0umRx4V1Hjw', assistant_id='asst_L3Fd7PZXMAAxdshcTsBH7uGt', content=[MessageContentText(text=Text(annotations=[], value='I will start by loading the data from the uploaded file to understand its structure and then proceed to create a bar plot of the total sum of Purchase Price expenditure per year.'), type='text')], created_at=1702323505, file_ids=[], metadata={}, object='thread.message', role='assistant', run_id='run_a3r5wQavxduDJ2WhQVDFdrlW', thread_id='thread_cepzPPkT74nYkduAy6aVrFTa')
#
#
# ...

# %% [markdown]
# **TASK: Confirm that the model created an image and download that ImageFile from OpenAI. Display it in the notebook.**

# %%
# Out:
# ThreadMessage(id='msg_jNKf7Ouzhwb4ngDYKUataqxE', assistant_id='asst_L3Fd7PZXMAAxdshcTsBH7uGt', content=[MessageContentImageFile(image_file=ImageFile(file_id='file-HyN6g3YMeg7qbhwQCZ4f21dz'), type='image_file'), MessageContentText(text=Text(annotations=[], value='The bar plot above visualizes the total sum of Purchase Price expenditure per year. Each bar represents the total amount spent on purchases for a specific year. This visualization provides a clear overview of the expenditure pattern over the years.'), type='text')], created_at=1702323528, file_ids=[], metadata={}, object='thread.message', role='assistant', run_id='run_a3r5wQavxduDJ2WhQVDFdrlW', thread_id='thread_cepzPPkT74nYkduAy6aVrFTa')

# %%
# Out:
# 'file-HyN6g3YMeg7qbhwQCZ4f21dz'

# %% [markdown]
# **TASK: Delete the Assistant and All Files (Optional)**
